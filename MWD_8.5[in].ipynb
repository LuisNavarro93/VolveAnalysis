# %% [markdown]
# # Analysis of MD-Log 8.5 [in] Section

# %%
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import numpy as np
import seaborn as sns

# %% [markdown]
# ## File directory

# %%
cd C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1
# Out:
# C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CEC9-4320
#
#  Directory of C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1
#
# 12/28/2020  03:39 PM    <DIR>          .
# 12/28/2020  03:39 PM    <DIR>          ..
# 12/28/2020  03:33 PM    <DIR>          .ipynb_checkpoints
# 05/12/2018  11:37 PM         2,758,660 00001.xml
# 05/12/2018  11:37 PM         2,767,969 00002.xml
# 05/12/2018  11:37 PM         2,693,592 00003.xml
# 05/12/2018  11:37 PM         2,323,284 00004.xml
# 05/12/2018  11:37 PM         1,967,122 00005.xml
# 05/12/2018  11:37 PM         2,023,185 00006.xml
# 05/12/2018  11:37 PM         1,969,207 00007.xml
# 05/12/2018  11:38 PM         1,999,368 00008.xml
# 05/12/2018  11:38 PM         2,111,823 00009.xml
# 12/28/2020  03:39 PM             3,451 Untitled.ipynb
#               10 File(s)     20,617,661 bytes
#                3 Dir(s)   3,859,718,144 bytes free

# %% [markdown]
# ## Reading `00001.xml`

# %%
f1 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00001.xml"

# %%
with open(f1) as f :
    data = f.read()

# %%
data_xml = BeautifulSoup(data,'xml')

# %%
set([str(tag.name) for tag in data_xml.find_all()])
# Out:
# {'axisDefinition',
#  'commonData',
#  'count',
#  'creationDate',
#  'curveDescription',
#  'dTimCreation',
#  'dTimLastChange',
#  'data',
#  'dataSource',
#  'direction',
#  'doubleValues',
#  'endIndex',
#  'indexCurve',
#  'indexType',
#  'log',
#  'logCurveInfo',
#  'logData',
#  'logs',
#  'maxIndex',
#  'minIndex',
#  'mnemonic',
#  'mnemonicList',
#  'name',
#  'nameWell',
#  'nameWellbore',
#  'nullValue',
#  'objectGrowing',
#  'order',
#  'pass',
#  'priv_dTimPriority',
#  'priv_dTimReceived',
#  'priv_ipLastChange',
#  'priv_ipOwner',
#  'priv_objectGrowing',
#  'priv_userLastChange',
#  'priv_userOwner',
#  'runNumber',
#  'serviceCompany',
#  'sourceName',
#  'startIndex',
#  'typeLogData',
#  'unit',
#  'unitList'}

# %%
data_xml.find_all("mnemonicList")
# Out:
# [<mnemonicList>DEPTH,TNPH_ECO_RT,TRPM_RT,ACTC,P28H_ECO_RT,GS_TREV,TTP2_RT,GS_TVA,RGX_RT,SHKRATE_RT,GS_G_C3,PMPT,CRPM_RT,MNSH_RT,GS_GASA,GS_TFLO,SHKPK_RT,DRPM,Stick_RT,SHKL_DH_ECO_RT,ECD_ECO_RT,CSTU_RT,CRS5,SPM4,MXSL_RT,GEN14_P,TVDE,DSTU_RT,RTSTAT,DTP2_RT,DEPT,RGX,CHP2_RT,ANP2_RT,ROBB_DH_ECO_RT,ANP4_RT,RHX,DTP1_RT,SPM3,INCL_CONT_RT,GS_SWOB,CHP1_RT,GS_MDOA,STPP_RT,GTF_RT,CH4U_RT,TRPM,RHX_RT,DTP3_RT,BDTI,GS_MWTI,SHKLV,DTCU_RT,BPHI_ECO_RT,TTP3_RT,GS_RPM,GS_TQA,GS_G_IC4,TFAR_DH_ECO_RT,SHKTOT_RT,TT4U_RT,TTP1_RT,GS_SPPA,UCAV_DH_ECO_RT,SPPA,CRS_CNAZI,GS_BDDI,MNSL_RT,ROBU_DH_ECO_RT,TTP4_RT,GS_G_NC5,GS_ROP,GS_G_C1,BITRUN,A40H_ECO_RT,DCRNT,MNST_RT,GEN13_P,GEN3_P,GTEMP,ITTI_RT,HV,GS_DVER,ECD_P,GEN7_P,GRMA_DH_ECO_RT,ROP5,CHSU_RT,GEN5_P,GEN6_P,AJAM_MWD,THKD,CRS4,HVM,DT4U_RT,DVER,CHCU_RT,VIBLAT_RT,GEN4_P,AZIM_CONT_RT,ROP,PASS_NAME,HKLO,MON_DH_ECO_RT,CHP3_RT,P40H_ECO_RT,GS_TDH,GEN9_P,TSTU_RT,SHKRSK_P,A28H_ECO_RT,GEN8_P,GEN12_P,NRPM_RT,DMEA,HKLD,VIBX_RT,GS_MTOA,TFDES,CRS_CNINC,GS_G_IC5,TSPM,GS_G_NC4,
# ...

# %% [markdown]
# # Needed logs for MWD
# `SWOB,TQA, GRMA_ECO_RT,DRPM,RPM,HKLD, TRPM, Stick_RT,GS_ROP, ROP, ,DHAT_DH_ECO_RT,ECD_ECO_RT, GS_SPPA, SPPA,TFL,GS_TFLO`

# %%
data_xml.find_all("unitList")
# Out:
# [<unitList>m,m3/m3,rpm,unitless,ohm.m,unitless,us,m3,unitless,1/s,ppm,h,rpm,us/ft,%,L/min,m/s2,rpm,rpm,unitless,g/cm3,unitless,unitless,1/min,us/ft,unitless,m,us/ft,unitless,us/ft,m,unitless,unitless,dega,g/cm3,dega,unitless,us/ft,1/min,dega,kkgf,unitless,g/cm3,unitless,dega,unitless,rpm,unitless,us/ft,h,g/cm3,unitless,us/ft,m3/m3,us,rpm,kN.m,ppm,1/s,unitless,us,us,kPa,cm,kPa,dega,m,us/ft,g/cm3,us,ppm,m/h,ppm,unitless,ohm.m,A,us/ft,unitless,unitless,degC,us/ft,unitless,m,g/cm3,unitless,gAPI,m/h,unitless,unitless,unitless,unitless,kkgf,unitless,unitless,us/ft,m,unitless,ft/s2,unitless,dega,m/h,unitless,kkgf,%,unitless,ohm.m,degC,unitless,us,unitless,ohm.m,unitless,unitless,unitless,m,kkgf,ft/s2,degC,dega,dega,ppm,1/min,ppm,1/min,cu,g/cm3,unitless,us/ft,rpm,1/s,dega,kPa,1/min,dega,m,degC,unitless,kkgf,min,us/ft,kPa,kkgf,kkgf,us/ft,%,dega,us,us/ft,unitless,kPa,gAPI,us/ft,us/ft,h,unitless,unitless,unitless,L/min,degC,us,ppm,unitless,kN.m,us/ft</unitList>]

# %%
data_xml.find_all("logCurveInfo")
# Out:
# [<logCurveInfo uid="TNPH_ECO_RT"><mnemonic>TNPH_ECO_RT</mnemonic><unit>m3/m3</unit><minIndex uom="m">3369.259</minIndex><maxIndex uom="m">3490.112</maxIndex><curveDescription>Thermal Neutron Porosity, Average</curveDescription><dataSource>ECO</dataSource><typeLogData>double</typeLogData></logCurveInfo>,
#  <logCurveInfo uid="TRPM_RT"><mnemonic>TRPM_RT</mnemonic><unit>rpm</unit><minIndex uom="m">3380.842</minIndex><maxIndex uom="m">3490.112</maxIndex><curveDescription>MWD Turbine RPM</curveDescription><dataSource>MWD</dataSource><typeLogData>double</typeLogData></logCurveInfo>,
#  <logCurveInfo uid="ACTC"><mnemonic>ACTC</mnemonic><unit>unitless</unit><minIndex uom="m">3343.656</minIndex><maxIndex uom="m">3490.112</maxIndex><curveDescription>Rig Mode</curveDescription><dataSource>Drilling</dataSource><typeLogData>double</typeLogData></logCurveInfo>,
# ...

# %% [markdown]
# ## DataFrame Construction

# %%
log_names = data_xml.find_all("mnemonicList")

# %%
units_names = data_xml.find_all("unitList")

# %%
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")

# %%
df_f1 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])

# %%
df_f1 = df_f1.replace("",np.NaN)

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Reading `00002.xml`

# %%
f2 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00002.xml"

# %%
with open(f2) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')

# %% [markdown]
# ## DataFrame Construction

# %%
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")

# %%
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")

# %%
df_f2 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])

# %%
df_f2 = df_f2.replace("",np.NaN)

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Reading `00003.xml`

# %%
f3 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00003.xml"
with open(f3) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')

# %% [markdown]
# ## DataFrame Construction

# %%
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f3 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])

# %%
df_f3 = df_f3.replace("",np.NaN)

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00004.xml` DataFrame

# %%
f4 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00004.xml"
with open(f4) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f4 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f4 = df_f4.replace("",np.NaN)

# %%
df_f4
# Out:
#        DEPTH/m TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless P28H_ECO_RT/ohm.m  \
# 0     3652.409               NaN         NaN           NaN               NaN
# 1     3652.418               NaN      3437.5             1             5.949
# 2     3652.434               NaN         NaN           NaN               NaN
# 3     3652.443               NaN         NaN           NaN               NaN
# 4     3652.458               NaN         NaN           NaN               NaN
# ...        ...               ...         ...           ...               ...
# 9995   3793.23               NaN         NaN           NaN               NaN
# 9996  3793.236               NaN     3085.94             1               NaN
# 9997  3793.251               NaN         NaN           NaN               NaN
# 9998  3793.276               NaN         NaN           NaN               NaN
# 9999  3793.297               NaN         NaN           NaN               NaN
#
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00005.xml` DataFrame

# %%
f5 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00005.xml"
with open(f5) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f5 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f5 = df_f5.replace("",np.NaN)

# %%
df_f5
# Out:
#        DEPTH/m  TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless  \
# 0     3793.321                NaN         NaN           NaN
# 1     3793.346                NaN         NaN           NaN
# 2     3793.367                NaN         NaN           NaN
# 3     3793.388                NaN     3085.94             1
# 4     3793.391                NaN         NaN           NaN
# ...        ...                ...         ...           ...
# 9995  4028.182                NaN         NaN           NaN
# 9996  4028.219                NaN         NaN           NaN
# 9997  4028.237                NaN         NaN             1
# 9998  4028.252                NaN         NaN           NaN
# 9999  4028.292                NaN         NaN           NaN
#
#       P28H_ECO_RT/ohm.m GS_TREV/unitless GS_TVA/m3 RGX_RT/unitless  \
# 0                   NaN              NaN       NaN             NaN
# 1                   NaN              NaN       NaN             NaN
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00006.xml` DataFrame

# %%
f6 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00006.xml"
with open(f6) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f6 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f6 = df_f6.replace("",np.NaN)

# %%
df_f6
# Out:
#        DEPTH/m  TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless  \
# 0     4028.328                NaN         NaN           NaN
# 1     4028.365                NaN         NaN           NaN
# 2     4028.389                NaN         NaN             1
# 3     4028.404                NaN         NaN           NaN
# 4     4028.438                NaN         NaN           NaN
# ...        ...                ...         ...           ...
# 9995  4301.703                NaN         NaN           NaN
# 9996  4301.743                NaN         NaN           NaN
# 9997  4301.783                NaN         NaN           NaN
# 9998  4301.795                NaN     3554.69             1
# 9999  4301.825                NaN         NaN           NaN
#
#       P28H_ECO_RT/ohm.m GS_TREV/unitless GS_TVA/m3 RGX_RT/unitless  \
# 0                   NaN              NaN       NaN             NaN
# 1                   NaN              NaN       NaN             NaN
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00007.xml` DataFrame

# %%
f7 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00007.xml"
with open(f7) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f7 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f7 = df_f7.replace("",np.NaN)

# %%
df_f7
# Out:
#        DEPTH/m  TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless  \
# 0     4301.825                NaN         NaN           NaN
# 1     4301.862                NaN         NaN           NaN
# 2     4301.898                NaN         NaN           NaN
# 3     4301.941                NaN         NaN           NaN
# 4     4301.947                NaN         NaN             1
# ...        ...                ...         ...           ...
# 9995  4541.203                NaN         NaN           NaN
# 9996  4541.215                NaN     3984.38             1
# 9997  4541.224                NaN         NaN           NaN
# 9998  4541.246                NaN         NaN           NaN
# 9999  4541.267                NaN         NaN           NaN
#
#       P28H_ECO_RT/ohm.m GS_TREV/unitless GS_TVA/m3 RGX_RT/unitless  \
# 0                   NaN              NaN       NaN             NaN
# 1                   NaN              NaN       NaN             NaN
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00008.xml` DataFrame

# %%
f8 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00008.xml"
with open(f8) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f8 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f8 = df_f8.replace("",np.NaN)

# %%
df_f8
# Out:
#        DEPTH/m  TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless  \
# 0     4541.267                NaN         NaN           NaN
# 1     4541.288                NaN         NaN           NaN
# 2      4541.31                NaN         NaN           NaN
# 3     4541.331                NaN         NaN           NaN
# 4     4541.352                NaN         NaN           NaN
# ...        ...                ...         ...           ...
# 9995  4802.011                NaN         NaN           NaN
# 9996  4802.042                NaN         NaN           NaN
# 9997  4802.078                NaN         NaN           NaN
# 9998  4802.115                NaN         NaN           NaN
# 9999  4802.124                NaN         NaN             1
#
#       P28H_ECO_RT/ohm.m GS_TREV/unitless GS_TVA/m3 RGX_RT/unitless  \
# 0                   NaN              NaN       NaN             NaN
# 1                   NaN              NaN       NaN             NaN
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Construction `00009.xml` DataFrame

# %%
f9 = r"C:\Users\Luis Navarro\Desktop\ProgrammingStuff\PetroleumData\Equinor Volve\Drilling\Norway-StatoilHydro-15_$47$_9-F-10\1\log\1\3\1\00009.xml"
with open(f9) as f :
    data = f.read()
data_xml = BeautifulSoup(data,'xml')
log_names = data_xml.find_all("mnemonicList")
units_names = data_xml.find_all("unitList")
header = [i+'/'+j for i,j in zip(log_names[0].string.split(","), units_names[0].string.split(","))]
data = data_xml.find_all("data")
df_f9 = pd.DataFrame(columns = header, data= [row.string.split(",") for row in data])
df_f9 = df_f9.replace("",np.NaN)

# %%
df_f9
# Out:
#        DEPTH/m TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless P28H_ECO_RT/ohm.m  \
# 0     4802.124               NaN         NaN             1               NaN
# 1     4802.148               NaN         NaN           NaN               NaN
# 2     4802.182               NaN         NaN           NaN               NaN
# 3     4802.222               NaN         NaN           NaN               NaN
# 4     4802.252               NaN         NaN           NaN               NaN
# ...        ...               ...         ...           ...               ...
# 9995  5062.588               NaN         NaN           NaN               NaN
# 9996  5062.624               NaN         NaN           NaN               NaN
# 9997  5062.658               NaN         NaN           NaN               NaN
# 9998  5062.728            0.4708     3281.25           NaN              2.36
# 9999  5062.765               NaN         NaN           NaN               NaN
#
# ...

# %%
del units_names
del data_xml
del log_names
del header 
del data

# %% [markdown]
# ## Individual DataFrames Depths

# %%
print("00001.xml:")
print("\tInitial:",df_f1["DEPTH/m"][0]) ; print("\tFinal:",df_f1["DEPTH/m"][9999])
print("00002.xml:")
print("\tInitial:",df_f2["DEPTH/m"].min()) ; print("\tFinal:",df_f2["DEPTH/m"].max())
print("00003.xml:")
print("\tInitial:",df_f3["DEPTH/m"].min()) ; print("\tFinal:",df_f3["DEPTH/m"].max())
print("00004.xml:")
print("\tInitial:",df_f4["DEPTH/m"].min()) ; print("\tFinal:",df_f4["DEPTH/m"].max())
print("00005.xml:")
print("\tInitial:",df_f5["DEPTH/m"].min()) ; print("\tFinal:",df_f5["DEPTH/m"].max())
print("00006.xml:")
print("\tInitial:",df_f6["DEPTH/m"].min()) ; print("\tFinal:",df_f6["DEPTH/m"].max())
print("00007.xml:")
print("\tInitial:",df_f7["DEPTH/m"].min()) ; print("\tFinal:",df_f7["DEPTH/m"].max())
print("00008.xml:")
print("\tInitial:",df_f8["DEPTH/m"].min()) ; print("\tFinal:",df_f8["DEPTH/m"].max())
print("00009.xml:")
print("\tInitial:",df_f9["DEPTH/m"].min()) ; print("\tFinal:",df_f9["DEPTH/m"].max())
# Out:
# 00001.xml:
# 	Initial: 799
# 	Final: 3490.253
# 00002.xml:
# 	Initial: 3490.262
# 	Final: 3575.49
# 00003.xml:
# 	Initial: 3575.496
# 	Final: 3652.409
# 00004.xml:
# 	Initial: 3652.409
# 	Final: 3793.297
# 00005.xml:
# 	Initial: 3793.321
# 	Final: 4028.292
# 00006.xml:
# 	Initial: 4028.328
# 	Final: 4301.825
# 00007.xml:
# 	Initial: 4301.825
# 	Final: 4541.267
# 00008.xml:
# 	Initial: 4541.267
# 	Final: 4802.124
# 00009.xml:
# 	Initial: 4802.124
# 	Final: 5062.765

# %%
df_f2
# Out:
#        DEPTH/m TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless P28H_ECO_RT/ohm.m  \
# 0     3490.262               NaN         NaN           NaN               NaN
# 1     3490.265           0.14467    3359.375             1             1.656
# 2     3490.271               NaN         NaN           NaN               NaN
# 3      3490.28               NaN         NaN           NaN               NaN
# 4     3490.292               NaN         NaN           NaN               NaN
# ...        ...               ...         ...           ...               ...
# 9995  3575.459               NaN         NaN           NaN               NaN
# 9996  3575.475               NaN         NaN           NaN               NaN
# 9997  3575.481               NaN         NaN           NaN               NaN
# 9998  3575.484               NaN         NaN           NaN               NaN
# 9999   3575.49               NaN         NaN           NaN               NaN
#
# ...

# %% [markdown]
# ## Final DataFrame

# %%
frames = [df_f1,df_f2,df_f3,df_f4,df_f5,df_f6,df_f7,df_f8,df_f9]

# %%
MWD_85 = pd.concat(frames)

# %%
MWD_85.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90000 entries, 0 to 9999
# Columns: 164 entries, DEPTH/m to MXP4_RT/us/ft
# dtypes: object(164)
# memory usage: 113.3+ MB

# %%
# %%time
print("Missing data:")
sns.heatmap(MWD_85.isnull(), cbar=False)
plt.show()
# Out:
# Missing data:
# Wall time: 2min 1s

# %%
MWD_85
# Out:
#        DEPTH/m TNPH_ECO_RT/m3/m3 TRPM_RT/rpm ACTC/unitless P28H_ECO_RT/ohm.m  \
# 0          799               NaN         NaN           NaN               NaN
# 1      799.999               NaN         NaN           NaN               NaN
# 2      800.999               NaN         NaN           NaN               NaN
# 3      804.001               NaN         NaN           NaN               NaN
# 4      805.001               NaN         NaN           NaN               NaN
# ...        ...               ...         ...           ...               ...
# 9995  5062.588               NaN         NaN           NaN               NaN
# 9996  5062.624               NaN         NaN           NaN               NaN
# 9997  5062.658               NaN         NaN           NaN               NaN
# 9998  5062.728            0.4708     3281.25           NaN              2.36
# 9999  5062.765               NaN         NaN           NaN               NaN
#
# ...

# %%
cols = MWD_85.columns

# %%
print('\n'.join(map(str, cols)))
# Out:
# DEPTH/m
# TNPH_ECO_RT/m3/m3
# TRPM_RT/rpm
# ACTC/unitless
# P28H_ECO_RT/ohm.m
# GS_TREV/unitless
# TTP2_RT/us
# GS_TVA/m3
# RGX_RT/unitless
# SHKRATE_RT/1/s
# GS_G_C3/ppm
# PMPT/h
# CRPM_RT/rpm
# MNSH_RT/us/ft
# GS_GASA/%
# GS_TFLO/L/min
# SHKPK_RT/m/s2
# DRPM/rpm
# Stick_RT/rpm
# SHKL_DH_ECO_RT/unitless
# ECD_ECO_RT/g/cm3
# CSTU_RT/unitless
# CRS5/unitless
# SPM4/1/min
# MXSL_RT/us/ft
# GEN14_P/unitless
# TVDE/m
# DSTU_RT/us/ft
# RTSTAT/unitless
# DTP2_RT/us/ft
# DEPT/m
# RGX/unitless
# CHP2_RT/unitless
# ANP2_RT/dega
# ROBB_DH_ECO_RT/g/cm3
# ANP4_RT/dega
# RHX/unitless
# DTP1_RT/us/ft
# SPM3/1/min
# INCL_CONT_RT/dega
# GS_SWOB/kkgf
# CHP1_RT/unitless
# GS_MDOA/g/cm3
# STPP_RT/unitless
# GTF_RT/dega
# CH4U_RT/unitless
# TRPM/rpm
# RHX_RT/unitless
# DTP3_RT/us/ft
# BDTI/h
# GS_MWTI/g/cm3
# SHKLV/unitless
# DTCU_RT/us/ft
# BPHI_ECO_RT/m3/m3
# TTP3_RT/us
# GS_RPM/rpm
# GS_TQA/kN.m
# GS_G_IC4/ppm
# TFAR_DH_ECO_RT/1/s
# SHKTOT_RT/unitless
# TT4U_RT/us
# TTP1_RT/us
# GS_SPPA/kPa
# ...

# %%
from pandas import DataFrame
MWD_8 = DataFrame(MWD_85, columns= ['DEPTH/m',"TVDE/m","GRMA_DH_ECO_RT/gAPI","TQA/kN.m","DRPM/rpm","GS_RPM/rpm","RPM/rpm","TRPM/rpm","Stick_RT/rpm",'SWOB/kkgf',"HKLD/kkgf","GS_SPPA/kPa","SPPA/kPa","GS_ROP/m/h","ROP/m/h","DHAT_DH_ECO_RT/degC","ECD_P/g/cm3","ECD_ECO_RT/g/cm3","TFLO/L/min","GS_TFLO/L/min"])

# %%
MWD_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DEPTH/m              90000 non-null  object
#  1   TVDE/m               10969 non-null  object
#  2   GRMA_DH_ECO_RT/gAPI  3141 non-null   object
#  3   TQA/kN.m             10969 non-null  object
#  4   DRPM/rpm             10969 non-null  object
#  5   GS_RPM/rpm           1695 non-null   object
#  6   RPM/rpm              10969 non-null  object
#  7   TRPM/rpm             7514 non-null   object
#  8   Stick_RT/rpm         7481 non-null   object
#  9   SWOB/kkgf            10969 non-null  object
#  10  HKLD/kkgf            10969 non-null  object
#  11  GS_SPPA/kPa          1695 non-null   object
#  12  SPPA/kPa             10969 non-null  object
#  13  GS_ROP/m/h           1695 non-null   object
#  14  ROP/m/h              10955 non-null  object
# ...

# %%
MWD_8 = MWD_8.apply(pd.to_numeric)

# %%
MWD_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DEPTH/m              90000 non-null  float64
#  1   TVDE/m               10969 non-null  float64
#  2   GRMA_DH_ECO_RT/gAPI  3141 non-null   float64
#  3   TQA/kN.m             10969 non-null  float64
#  4   DRPM/rpm             10969 non-null  float64
#  5   GS_RPM/rpm           1695 non-null   float64
#  6   RPM/rpm              10969 non-null  float64
#  7   TRPM/rpm             7514 non-null   float64
#  8   Stick_RT/rpm         7481 non-null   float64
#  9   SWOB/kkgf            10969 non-null  float64
#  10  HKLD/kkgf            10969 non-null  float64
#  11  GS_SPPA/kPa          1695 non-null   float64
#  12  SPPA/kPa             10969 non-null  float64
#  13  GS_ROP/m/h           1695 non-null   float64
#  14  ROP/m/h              10955 non-null  float64
# ...

# %%
# %%time
print("Missing data:")
sns.heatmap(MWD_8.isnull(), cbar=False)
plt.show()
# Out:
# Missing data:
# Wall time: 24.9 s

# %%
MWD_8.columns
# Out:
# Index(['DEPTH/m', 'TVDE/m', 'GRMA_DH_ECO_RT/gAPI', 'TQA/kN.m', 'DRPM/rpm',
#        'GS_RPM/rpm', 'RPM/rpm', 'TRPM/rpm', 'Stick_RT/rpm', 'SWOB/kkgf',
#        'HKLD/kkgf', 'GS_SPPA/kPa', 'SPPA/kPa', 'GS_ROP/m/h', 'ROP/m/h',
#        'DHAT_DH_ECO_RT/degC', 'ECD_P/g/cm3', 'ECD_ECO_RT/g/cm3', 'TFLO/L/min',
#        'GS_TFLO/L/min'],
#       dtype='object')

# %%
print("Percentage of missing values per column:")
print("\tTVDE/m",MWD_8["TVDE/m"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tGRMA_DH_ECO_RT/gAPI",MWD_8["GRMA_DH_ECO_RT/gAPI"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tTQA/kN.m",MWD_8["TQA/kN.m"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tDRPM/rpm",MWD_8["DRPM/rpm"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tGS_RPM/rpm",MWD_8["GS_RPM/rpm"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tRPM/rpm",MWD_8["RPM/rpm"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tTRPM/rpm",MWD_8["TRPM/rpm"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tStick_RT/rpm",MWD_8["Stick_RT/rpm"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tSWOB/kkgf",MWD_8["SWOB/kkgf"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tHKLD/kkgf",MWD_8["HKLD/kkgf"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tGS_SPPA/kPa",MWD_8["GS_SPPA/kPa"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tSPPA/kPa",MWD_8["SPPA/kPa"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tGS_ROP/m/h",MWD_8["GS_ROP/m/h"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tROP/m/h",MWD_8["ROP/m/h"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tDHAT_DH_ECO_RT/degC",MWD_8["DHAT_DH_ECO_RT/degC"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tECD_P/g/cm3",MWD_8["ECD_P/g/cm3"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tTFLO/L/min",MWD_8["TFLO/L/min"].isnull().sum() * 100/ len(MWD_8),"%")
print("\tGS_TFLO/L/min",MWD_8["GS_TFLO/L/min"].isnull().sum() * 100/ len(MWD_8),"%")
# Out:
# Percentage of missing values per column:
# 	TVDE/m 87.81222222222222 %
# 	GRMA_DH_ECO_RT/gAPI 96.51 %
# 	TQA/kN.m 87.81222222222222 %
# 	DRPM/rpm 87.81222222222222 %
# 	GS_RPM/rpm 98.11666666666666 %
# 	RPM/rpm 87.81222222222222 %
# 	TRPM/rpm 91.6511111111111 %
# 	Stick_RT/rpm 91.68777777777778 %
# 	SWOB/kkgf 87.81222222222222 %
# 	HKLD/kkgf 87.81222222222222 %
# 	GS_SPPA/kPa 98.11666666666666 %
# 	SPPA/kPa 87.81222222222222 %
# 	GS_ROP/m/h 98.11666666666666 %
# 	ROP/m/h 87.82777777777778 %
# 	DHAT_DH_ECO_RT/degC 97.75222222222222 %
# 	ECD_P/g/cm3 98.6 %
# 	TFLO/L/min 87.81333333333333 %
# 	GS_TFLO/L/min 98.11666666666666 %

# %%
del MWD_8["GRMA_DH_ECO_RT/gAPI"]
del MWD_8["GS_RPM/rpm"]
del MWD_8["GS_SPPA/kPa"]
del MWD_8["GS_ROP/m/h"]
del MWD_8["DHAT_DH_ECO_RT/degC"]
del MWD_8["ECD_P/g/cm3"]
del MWD_8["GS_TFLO/L/min"]

# %%
MWD_8
# Out:
#        DEPTH/m      TVDE/m  TQA/kN.m  DRPM/rpm  RPM/rpm  TRPM/rpm  \
# 0      799.000         NaN       NaN       NaN      NaN       NaN
# 1      799.999         NaN       NaN       NaN      NaN       NaN
# 2      800.999         NaN       NaN       NaN      NaN       NaN
# 3      804.001         NaN       NaN       NaN      NaN       NaN
# 4      805.001         NaN       NaN       NaN      NaN       NaN
# ...        ...         ...       ...       ...      ...       ...
# 9995  5062.588         NaN       NaN       NaN      NaN       NaN
# 9996  5062.624         NaN       NaN       NaN      NaN       NaN
# 9997  5062.658         NaN       NaN       NaN      NaN       NaN
# 9998  5062.728  2861.05092  18.39845    199.64   199.64       NaN
# 9999  5062.765         NaN       NaN       NaN      NaN       NaN
#
#       Stick_RT/rpm  SWOB/kkgf   HKLD/kkgf     SPPA/kPa    ROP/m/h  \
# 0              NaN        NaN         NaN          NaN        NaN
# ...
